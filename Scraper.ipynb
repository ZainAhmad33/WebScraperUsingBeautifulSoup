# %%
import requests 
from bs4 import BeautifulSoup 
import pandas as pd

# %% [markdown]
# # Lahore Campus Scrapper

# %%
data_lhr = {
            "ID":[],
            "Name": [],
            "Designation":[],
            "HEC Approved PHD Supervisor":[],
            "Highest Education":[],
            "Email":[],
            "Department":[],
            "Extension":[],
            "ImageURL":[]
           }
    
def process_LHR_faculties(faculties, dept):
    '''
    This function processes all the list of Faculties (in HTML) and parses them in a Dictionary.
    The dictionary contains a Faculty member's ID, Name, Designation, HEC Accproved Supervisor,
    Highest Education, Email, Department, Extension, and ImageURL.
    '''
    for faculty in faculties:
        data_lhr["Department"].append(dept)
        
        data_lhr["Name"].append(faculty.find('h5', class_='text-center').text)
        #print(name)
        desig_tokens = faculty.find('p', class_='text-center').text.strip().split('\n')
        data_lhr["Designation"].append(desig_tokens[0].strip())
        approved_supervisor = data_lhr["HEC Approved PHD Supervisor"].append(True if 'HEC Approved' in desig_tokens[-1].strip() else False)
        #print(desig)
        #print(approved_supervisor)
        data_lhr["Email"].append(faculty.find('p', class_='mb-0').text)
        #print(email)
        try:
            id = int(faculty.find('a', class_='faculty-link')['href'].split('/')[-1])
        except:
            id = None
        data_lhr["ID"].append(id)
        #print(id)
        data_lhr["ImageURL"].append('https://lhr.nu.edu.pk'+faculty.find('img', class_='card-img-top')['src'])
        #print(img_url)
        faculty_link = 'https://lhr.nu.edu.pk' + faculty.find('a', class_='faculty-link')['href']
        #print(faculty_link)
        if faculty_link is not None:
            r_2 = requests.get(faculty_link)
            s = BeautifulSoup(r_2.content, 'html.parser') 
            try:
                ext = int(s.find('div', class_='facultyCard').find('p', class_='mt-0').find('span', class_='small').text.split(' ')[-1][4:])
            except:
                ext=None
            
            data_lhr["Extension"].append(ext)
            
            #print(ext)
            try:
                highest_education = s.find('div', class_='text-justify').findAll('li')[0].text.strip()
            except:
                highest_education = None
                
            data_lhr["Highest Education"].append(highest_education)
                
            #print(education)
        else:
            data_lhr["Highest Education"].append(None)
            data_lhr["Extension"].append(None)

# %%
def get_LHR_Faculty_Data():
    '''
    This function scrapes http://lhr.nu.edu.pk for all the Faculty data of all departments.
    It also uses process_LHR_faculties() function to parse the gathered data in a dictionary.
    '''
    # School of Computing
    URL = "http://lhr.nu.edu.pk/fsc/faculty/"
    r = requests.get(URL) 
    soup = BeautifulSoup(r.content, 'html.parser') 
    containers = soup.findAll('div', class_='container')
    
    for cont in containers:
        dept = cont.find('h1', class_='mb-2')
        if dept != None:
            dept_tokens = dept.text.split(' ')
            dept = dept_tokens[2] + " " + dept_tokens[3]
            #print(dept)
            faculties = cont.findAll('div', class_ = 'facultyCard')
            process_LHR_faculties(faculties, dept)
    
    # Electrical Engineering
    URL = "http://lhr.nu.edu.pk/ee/faculty/"
    r = requests.get(URL) 
    soup = BeautifulSoup(r.content, 'html.parser') 
    faculties = soup.findAll('div', class_='facultyCard')
    process_LHR_faculties(faculties, 'Electrical Engineering')
    
    # Civil Engineering
    URL = "http://lhr.nu.edu.pk/cv/faculty/"
    r = requests.get(URL) 
    soup = BeautifulSoup(r.content, 'html.parser') 
    faculties = soup.findAll('div', class_='facultyCard')
    process_LHR_faculties(faculties, 'Civil Engineering')
    
    # School of Management
    URL = "http://lhr.nu.edu.pk/fsm/faculty/"
    r = requests.get(URL) 
    soup = BeautifulSoup(r.content, 'html.parser') 
    faculties = soup.findAll('div', class_='facultyCard')
    process_LHR_faculties(faculties, 'Management'), data_lhr
    
    # Humanities
    URL = "http://lhr.nu.edu.pk/ss/faculty/"
    r = requests.get(URL) 
    soup = BeautifulSoup(r.content, 'html.parser') 
    faculties = soup.findAll('div', class_='facultyCard')
    process_LHR_faculties(faculties, 'Science & Humanities')

# %%
get_LHR_Faculty_Data()

# %%
df_lhr = pd.DataFrame(data_lhr)

# %%
df_lhr
# Out:
#          ID                      Name          Designation  \
# 0    1238.0          Dr. Kashif Zafar            Professor
# 1    4391.0  Dr. Asif Mahmood Gillani            Professor
# 2    5424.0         Dr. Hammad Naveed            Professor
# 3    6174.0            Dr. Arshad Ali  Associate Professor
# 4    6113.0           Dr. Asma Naseer  Associate Professor
# ..      ...                       ...                  ...
# 179  6420.0         Ms. Nokhaiz Zahra           Instructor
# 180  6181.0            Ms. Rida Ahmed           Instructor
# 181  6555.0              Ms. Aqsa Naz   Lecturer (English)
# 182     NaN    Mr. Hafiz Umair Gulzar  Lecturer (Islamiat)
# 183  6548.0          Ms. Rubab Arshad   Lecturer (English)
#
#      HEC Approved PHD Supervisor  \
# 0                           True
# 1                           True
# 2                           True
# 3                           True
# 4                           True
# ..                           ...
# 179                        False
# 180                        False
# 181                        False
# 182                        False
# 183                        False
#
#                                      Highest Education  \
# 0    Ph.D(Computer Science), NUCES, Islamabad, Paki...
# 1    Ph.D(Computing), University of Patras , Greece...
# 2    Ph.D. (Bioengineering), The University of Illi...
# 3    PhD (CS), University of Paris VI (UPMC) Paris,...
# 4                        PhD (CS), NUCES, Lahore, 2018
# ..                                                 ...
# 179                       MA, Virtual University(2020)
# 180  BS (English), Fatima Jinnah Women University, ...
# 181               M.Phil (English), UCP, Lahore (2022)
# 182       M.Phil (Islamic Studies), GCU, Lahore (2019)
# 183     MS (Applied Linguistics), NUCES, Lahore (2022)
#
#                        Email            Department  Extension  \
# 0     kashif.zafar@nu.edu.pk      Computer Science      221.0
# 1      asif.gilani@nu.edu.pk      Computer Science      291.0
# 2    hammad.naveed@nu.edu.pk      Computer Science      227.0
# 3      arshad.ali1@nu.edu.pk      Computer Science      406.0
# 4      asma.naseer@nu.edu.pk      Computer Science      410.0
# ..                       ...                   ...        ...
# 179  nokhaiz.zahra@nu.edu.pk  Science & Humanities      324.0
# 180     rida.ahmed@nu.edu.pk  Science & Humanities      363.0
# 181       aqsa.naz@nu.edu.pk  Science & Humanities      324.0
# 182   umair.gulzar@nu.edu.pk  Science & Humanities      207.0
# 183   rubab.arshad@nu.edu.pk  Science & Humanities      286.0
#
#                                               ImageURL
# 0    https://lhr.nu.edu.pk/media/Faculty/02_-_Dr._K...
# 1    https://lhr.nu.edu.pk/media/Faculty/03_-_Dr._A...
# 2    https://lhr.nu.edu.pk/media/Faculty/01_-_Dr._H...
# 3    https://lhr.nu.edu.pk/media/Faculty/04_-_Dr._A...
# 4    https://lhr.nu.edu.pk/media/Faculty/Dr_Asma_Na...
# ..                                                 ...
# 179  https://lhr.nu.edu.pk/media/Faculty/165_-_Nokh...
# 180  https://lhr.nu.edu.pk/media/Faculty/6181-remov...
# 181  https://lhr.nu.edu.pk/media/Faculty/161_-_Aqsa...
# 182  https://lhr.nu.edu.pk/media/Faculty/163_-_Hafi...
# 183  https://lhr.nu.edu.pk/media/Faculty/162_-_Ruba...
#
# [184 rows x 9 columns]

# %%
df_lhr.dtypes
# Out:
# ID                             float64
# Name                            object
# Designation                     object
# HEC Approved PHD Supervisor       bool
# Highest Education               object
# Email                           object
# Department                      object
# Extension                      float64
# ImageURL                        object
# dtype: object

# %%
df_lhr = df_lhr.convert_dtypes()

# %%
df_lhr.dtypes  # no predefined EMAIL or URL datatypes so considereing them as Strings
# Out:
# ID                               Int64
# Name                            string
# Designation                     string
# HEC Approved PHD Supervisor    boolean
# Highest Education               string
# Email                           string
# Department                      string
# Extension                        Int64
# ImageURL                        string
# dtype: object

# %%
df_lhr.to_csv('lhr.csv')

# %% [markdown]
# # Faisalabad Capmus Scrapper

# %%
data_cfd = {
            "ID":[],
            "Name": [],
            "Designation":[],
            "HEC Approved PHD Supervisor":[],
            "Highest Education":[],
            "Email":[],
            "Department":[],
            "Extension":[],
            "ImageURL":[]
           }
def process_CFD_Faculties(faculties):
    '''
    This function processes all the list of Faculties in CFD Campus (in HTML) and parses them in a Dictionary.
    The dictionary contains a Faculty member's ID, Name, Designation, HEC Accproved Supervisor,
    Highest Education, Email, Department, Extension, and ImageURL.
    '''
    for faculty in faculties:
        imageURL = faculty.find('img')['src']
        details = faculty.find('div', 'unitech-teacher__details')
        desig = details.find('h6').text.strip()
        name = details.find('a').text.strip()
        email = details.find('p', class_=None).text
        try:
            hec_approved = True if "HEC approved" in details.find('p', class_='hec').text.strip() else False
        except:
            hec_approved = False
        link = details.find('a')['href']
        if link is not None:
            #id_ = link.split('/')[-2]
            r2 = requests.get(link)
            s2 = BeautifulSoup(r2.content, 'html.parser')
            try:
                id_ = int(s2.find('link', {"rel":"shortlink"})['href'].split('=')[-1])
            except:
                id_ = None
            try:
                ext = int(s2.find('ul', class_='teacher__address').findAll('li')[-1].text.strip().split('\n')[-1].strip())
            except:
                ext = None
            try:
                dept = s2.find('ul', class_='teacher__address').findAll('li')[0].text.strip()
            except:
                dept = None
            try:
                highest_education = s2.find('div', class_='htc__skill__container progress__bar--2').find('li').text
            except:
                try:
                    highest_education = s2.find('div', class_='htc__skill__container progress__bar--2').find('p').text
                except:
                    highest_education = None
        else:
            id_ = None
            ext = None
            dept = None
            highest_education = None
            
        data_cfd['ID'].append(id_)
        data_cfd['Name'].append(name)
        data_cfd['Designation'].append(desig)
        data_cfd['HEC Approved PHD Supervisor'].append(hec_approved)
        data_cfd['Highest Education'].append(highest_education)
        data_cfd['Department'].append(dept)
        data_cfd['Extension'].append(ext)
        data_cfd['Email'].append(email)
        data_cfd['ImageURL'].append(imageURL)

# %%
def get_CFD_Faculty_Data():
    '''
    This function scrapes https://cfd.nu.edu.pk for all the Faculty data of all departments.
    It also uses process_CFD_Faculties() function to parse the gathered data in a dictionary.
    '''
    
    URL = "https://cfd.nu.edu.pk/department-cs/"
    r = requests.get(URL)
    soup = BeautifulSoup(r.content, 'html.parser') 
    faculties = soup.findAll('div', 'unitech-teacher')
    process_CFD_Faculties(faculties)
    
    URL = "https://cfd.nu.edu.pk/department-se/"
    r = requests.get(URL)
    soup = BeautifulSoup(r.content, 'html.parser') 
    faculties = soup.findAll('div', 'unitech-teacher')
    #print(len(faculties))
    process_CFD_Faculties(faculties)
    
    URL = "https://cfd.nu.edu.pk/department-ee/"
    r = requests.get(URL)
    soup = BeautifulSoup(r.content, 'html.parser') 
    faculties = soup.findAll('div', 'unitech-teacher')
    #print(len(faculties))
    process_CFD_Faculties(faculties)
    
    URL = "https://cfd.nu.edu.pk/department-sh/"
    r = requests.get(URL)
    soup = BeautifulSoup(r.content, 'html.parser') 
    faculties = soup.findAll('div', 'unitech-teacher')
    #print(len(faculties))
    process_CFD_Faculties(faculties)
    
    URL = "https://cfd.nu.edu.pk/department-fsm/"
    r = requests.get(URL)
    soup = BeautifulSoup(r.content, 'html.parser') 
    faculties = soup.findAll('div', 'unitech-teacher')
    #print(len(faculties))
    process_CFD_Faculties(faculties)

# %%
get_CFD_Faculty_Data()

# %%
df_cfd = pd.DataFrame(data_cfd)

# %%
df_cfd
# Out:
#          ID                 Name                Designation  \
# 0      6074   Dr. Muhammad Ahmad  Associate Professor & HOD
# 1      4748  Dr. Shahzad Sarfraz                  Professor
# 2    507933       Dr. Anwar Shah        Assistant Professor
# 3      4752       Dr. Bilal Khan        Assistant Professor
# 4      4772     Dr. Hashim Yasin        Assistant Professor
# ..      ...                  ...                        ...
# 101    4858      Dr. Umar Farooq        Assistant Professor
# 102  508478      Mr. Ahmad Salah                   Lecturer
# 103  508457       Ms. Amna Babar                   Lecturer
# 104    4865   Mr. Hafiz Muhammad                   Lecturer
# 105    4866   Mr. Muhammad Nasif                   Lecturer
#
#      HEC Approved PHD Supervisor  \
# 0                           True
# 1                           True
# 2                           True
# 3                           True
# 4                           True
# ..                           ...
# 101                         True
# 102                        False
# 103                        False
# 104                        False
# 105                        False
#
#                                      Highest Education  \
# 0    Doctor of Philosophy (Hyperspectral Imaging) (...
# 1    Ph.D. in Remote Sensing Image Processing AIT, ...
# 2          PhD Computer Sciences, FAST-NUCES, Peshawar
# 3     Ph.D. (Computer Science & Engineering), Dongg...
# 4    Ph.D. (Computer Science), University of Bonn, ...
# ..                                                 ...
# 101  PhD (Finance), COMSATS University Islamabad, L...
# 102  Chartered Financial Analyst (CFA), institute, ...
# 103  MS, Innovation and Entrepreneurship, 2022\nBBA...
# 104  MBA, FAST National University of computer and ...
# 105  M.S(Finance), Air University, Islamabad, Pakis...
#
#                          Email                      Department  Extension  \
# 0           dr.ahmad@nu.edu.pk  Department of Computer Science      160.0
# 1    shahzad.sarfraz@nu.edu.pk  Department of Computer Science      102.0
# 2         Anwar.Shah@nu.edu.pk  Department of Computer Science      131.0
# 3         khan.bilal@nu.edu.pk  Department of Computer Science      126.0
# 4       hashim.yasin@nu.edu.pk  Department of Computer Science      165.0
# ..                         ...                             ...        ...
# 101      umar.farooq@nu.edu.pk       FAST School of Management      264.0
# 102      ahmad.salah@nu.edu.pk       FAST School of Management      256.0
# 103    amna.Tirmizey@nu.edu.pk       FAST School of Management        NaN
# 104     Zeeshan.raza@nu.edu.pk       FAST School of Management      265.0
# 105          m.nasif@nu.edu.pk       FAST School of Management      261.0
#
#                                               ImageURL
# 0    https://cfd.nu.edu.pk/wp-content/uploads/2020/...
# 1    https://cfd.nu.edu.pk/wp-content/uploads/2019/...
# 2    https://cfd.nu.edu.pk/wp-content/uploads/2022/...
# 3    https://cfd.nu.edu.pk/wp-content/uploads/2019/...
# 4    https://cfd.nu.edu.pk/wp-content/uploads/2019/...
# ..                                                 ...
# 101  https://cfd.nu.edu.pk/wp-content/uploads/2019/...
# 102  https://cfd.nu.edu.pk/wp-content/uploads/2023/...
# 103  https://cfd.nu.edu.pk/wp-content/uploads/2023/...
# 104  https://cfd.nu.edu.pk/wp-content/uploads/2019/...
# 105  https://cfd.nu.edu.pk/wp-content/uploads/2019/...
#
# [106 rows x 9 columns]

# %%
df_cfd.dtypes
# Out:
# ID                               int64
# Name                            object
# Designation                     object
# HEC Approved PHD Supervisor       bool
# Highest Education               object
# Email                           object
# Department                      object
# Extension                      float64
# ImageURL                        object
# dtype: object

# %%
df_cfd = df_cfd.convert_dtypes()

# %%
df_cfd.dtypes
# Out:
# ID                               Int64
# Name                            string
# Designation                     string
# HEC Approved PHD Supervisor    boolean
# Highest Education               string
# Email                           string
# Department                      string
# Extension                        Int64
# ImageURL                        string
# dtype: object

# %%
df_cfd.to_csv('cfd.csv')

# %% [markdown]
# # Peshawar Campus Scrapper

# %%
data_pwr = {
            "ID":[],
            "Name": [],
            "Designation":[],
            "HEC Approved PHD Supervisor":[],
            "Highest Education":[],
            "Email":[],
            "Department":[],
            "Extension":[],
            "ImageURL":[]
           }
def process_PWR_Faculties(faculties):
    '''
    This function processes all the list of Faculties in Peshawar Campus (in HTML) and parses them in a Dictionary.
    The dictionary contains a Faculty member's ID, Name, Designation, HEC Accproved Supervisor,
    Highest Education, Email, Department, Extension, and ImageURL.
    '''
    for faculty in faculties:
        img_url = 'http://pwr.nu.edu.pk/' + faculty.find('img')['src']
        name = faculty.find('a', class_='text-theme-color-2').text.strip()
        link = 'http://pwr.nu.edu.pk/' + faculty.find('a', class_='text-theme-color-2')['href']
        desig = faculty.find('h5', class_='text-theme-color').text.strip()
        mail = faculty.find('li').find('a')['href'][7:]
        
        if link is not None:
            id_ = int(link.split('=')[-1])
            r2 = requests.get(link)
            s2 = BeautifulSoup(r2.content, 'html.parser')

            dept = s2.findAll('h5', class_=None)[-1].text
            try:
                hec_approved = True if 'HEC Approved' in s2.findAll('h5', class_=None)[0].text else False
            except:
                hec_approved = None
            highest_education = s2.find('div', {"id":'education'}).find('li').text.strip()
            try:
                ext = int(s2.find('div', {"id":'contact'}).find('a', {"class":"text-gray"}).text.split('|')[-1].strip()[4:])
            except:
                ext = None
        else:
            id_ = None
            dept = None
            hec_approved = None
            highest_education = None
            ext = None
        
        data_pwr['ID'].append(id_)
        data_pwr['Name'].append(name)
        data_pwr['Designation'].append(desig)
        data_pwr['HEC Approved PHD Supervisor'].append(hec_approved)
        data_pwr['Highest Education'].append(highest_education)
        data_pwr['Department'].append(dept)
        data_pwr['Extension'].append(ext)
        data_pwr['Email'].append(mail)
        data_pwr['ImageURL'].append(img_url)

# %%
def get_PWR_Faculty_Data():
    '''
    This function scrapes https://pwr.nu.edu.pk for all the Faculty data of all departments.
    It also uses process_PWR_Faculties() function to parse the gathered data in a dictionary.
    '''
    url = "http://pwr.nu.edu.pk/cs-faculty/"
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    faculties = soup.findAll('div', class_='team-members')
    process_PWR_Faculties(faculties)
    
    url = "http://pwr.nu.edu.pk/ee-faculty/"
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    faculties = soup.findAll('div', class_='team-members')
    process_PWR_Faculties(faculties)
    
    url = "http://pwr.nu.edu.pk/sh-faculty/"
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    faculties = soup.findAll('div', class_='team-members')
    process_PWR_Faculties(faculties)

# %%
get_PWR_Faculty_Data()

# %%
df_pwr = pd.DataFrame(data_pwr)

# %%
df_pwr
# Out:
#     ID                  Name                     Designation  \
# 0    1  Dr. Hafeez Ur Rehman       Associate Professor & HoD
# 1    2   Dr. Omar Usman Khan  Associate Professor & Director
# 2    3       Dr. Nouman Azam             Associate Professor
# 3    4   Dr. Mohammad Nauman             Associate Professor
# 4    5      Dr. Taimoor Khan             Assistant Professor
# 5    6         Dr. Bahar Ali             Assistant Professor
# 6    7   Dr. Musadaq Mansoor             Assistant Professor
# 7    8     Dr. Muhammad Amin             Assistant Professor
# 8    9          Fazl-e-Basit             Assistant Professor
# 9   10  Shoaib Muhammad Khan             Assistant Professor
# 10  11     Shakir Ullah Shah             Assistant Professor
# 11  12             Waqas Ali                        Lecturer
# 12  13           Zeshan Khan                        Lecturer
# 13  14       Ms. Sara Rehmat                        Lecturer
# 14  15           Maryam Omar                        Lecturer
# 15  16         Salma Kulsoom                        Lecturer
# 16  43       Ms. Mashal Khan                        Lecturer
# 17  57        Usama Musharaf                        Lecturer
# 18  61        Khuram Shahzad                      Instructor
# 19  62        Muhammad Usman                      Instructor
# 20  83        Hurmat Hidayat                      Instructor
# 21  84           Fariba Laiq                      Instructor
# 22  78    Dr. M Usman Abbasi       Assistant Professor & HoD
# 23  77        Dr. Asif Iqbal             Assistant Professor
# 24  76       Dr. Suleman Mir             Assistant Professor
# 25  75       Mr. M Asif Khan             Assistant Professor
# 26  74       Mr. Rahat Ehsan             Assistant Professor
# 27  73      Mr. Maqsood Khan             Assistant Professor
# 28  72    Mr. Muhammad Kamil                        Lecturer
# 29  71  Mr. Syed Mohsin Shah                        Lecturer
# 30  70      Mr. Waseem Ullah                    Lab Engineer
# 31  69      Mr. Kashif Javed                    Lab Engineer
# 32  68     Mr. Muneeb Suhail                    Lab Engineer
# 33  67    Mr. Nouman Shabbir                    Lab Engineer
# 34  65       Ms. Anum Rashad                    Lab Engineer
# 35  88       Dr. Ihsan Ullah             Assistant Professor
# 36  54      Mr. Osama Sohrab                        Lecturer
# 37  53       Mr. Ikram Ullah             Assistant Professor
# 38  52         Mr. Askar Ali                        Lecturer
# 39  51       Ms. Noreen Shah                        Lecturer
# 40  50       Ms. Abida Farid                        Lecturer
#
#     HEC Approved PHD Supervisor  \
# 0                          True
# 1                          True
# 2                          True
# 3                          True
# 4                          True
# 5                          True
# 6                         False
# 7                         False
# 8                         False
# 9                         False
# 10                        False
# 11                        False
# 12                        False
# 13                        False
# 14                        False
# 15                        False
# 16                        False
# 17                        False
# 18                        False
# 19                        False
# 20                        False
# 21                        False
# 22                         True
# 23                         True
# 24                        False
# 25                        False
# 26                        False
# 27                        False
# 28                        False
# 29                        False
# 30                        False
# 31                        False
# 32                        False
# 33                        False
# 34                        False
# 35                         True
# 36                        False
# 37                        False
# 38                        False
# 39                        False
# 40                        False
#
#                                     Highest Education  \
# 0   Ph.D. in Computer and Control Engineering, Pol...
# 1   Ph.D. (Computer And Control Engineering), Poli...
# 2     Ph.D. (CS), University of Regina, Canada (2014)
# 3   PhD(IT), University of Kuala Lumpur, Malaysia ...
# 4   Ph.D. (Computer Science), Bahria University Is...
# 5   PhD, Three-way Clustering (Machine Learning), ...
# 6   PhD Computer Science (Machine Learning / Bioin...
# 7          PhD (Computer Science), IM Sciences (2022)
# 8   M.S(Computer Science), NUST, Rawalpindi, Pakis...
# 9   M.S(Computer Science), NUCES, Islamabad, Pakis...
# 10  M.S(Computer Science), Foundation University, ...
# 11  MS(Computer Science), University of Peshawar, ...
# 12  BS (CS),2012, Muhammad Ali Jinnah University, ...
# 13                                                  #
# 14  MS (Computer Science), National University of ...
# 15                    MS Computer Science, SEECS NUST
# 16  MS Information Security  2020 SEECS NUST Islam...
# 17  MS(CS), CECOS University of IT & Emerging Scie...
# 18  In progress -  MS in Data Science at FAST- Nat...
# 19  Doing MS in Data Science at FAST- National Uni...
# 20  MS (Computer Science), UET Peshawar - (In prog...
# 21          BS Computer Science, IMSciences Peshawar.
# 22  PhD (Electrical Engineering), National Univers...
# 23                                                  #
# 24  PhD(Electrical Engineering),National Universit...
# 25  M.Sc(Engineering), University of Leeds, United...
# 26  M.Sc(Telecom Engineering), Melbourne Universit...
# 27  M.Sc(Electrical Engineering), Blekings Institu...
# 28  B.S(Electronic Engineering), Sir Syed Universi...
# 29  B.Sc(Electrical Engineering), UET, Peshawar, P...
# 30  B.E(Electrical Engineering), NWFP UET Peshawar...
# 31    B.S(Telecom Engineering), FAST, Pakistan (2012)
# 32  B.S(Electrical Engineering), FAST NUCES, Pakis...
# 33                                                  #
# 34               BS(EE),NUCES,Peshawar,Pakistan(2014)
# 35  PhD (Finance),  Institute of Management Scienc...
# 36  M.S (Applied Mathematics), Ghulam Ishaq Khan I...
# 37                                                  #
# 38                                                  #
# 39               Ph.D. Scholar (Coursework completed)
# 40  •\tMPhil in English Language & Communication f...
#
#                         Email              Department  Extension  \
# 0   hafeez.urrehman@nu.edu.pk        Computer Science        107
# 1         omar.khan@nu.edu.pk        Computer Science        103
# 2       nouman.azam@nu.edu.pk        Computer Science        134
# 3   mohammad.nauman@nu.edu.pk        Computer Science        126
# 4      taimoor.khan@nu.edu.pk        Computer Science        127
# 5         bahar.ali@nu.edu.pk        Computer Science        122
# 6   musadaq.mansoor@nu.edu.pk        Computer Science        130
# 7     muhammad.amin@nu.edu.pk        Computer Science        146
# 8        fazl.basit@nu.edu.pk        Computer Science        110
# 9       shoaib.khan@nu.edu.pk        Computer Science        144
# 10     shakir.ullah@nu.edu.pk        Computer Science        108
# 11        waqas.ali@nu.edu.pk        Computer Science        144
# 12      zeshan.khan@nu.edu.pk        Computer Science        145
# 13      sara.rehmat@nu.edu.pk        Computer Science        122
# 14      maryam.omar@nu.edu.pk        Computer Science        122
# 15    Salma.kulsoom@nu.edu.pk        Computer Science        147
# 16      mashal.khan@nu.edu.pk        Computer Science        147
# 17   usama.musharaf@nu.edu.pk        Computer Science        145
# 18   khuram.shahzad@nu.edu.pk        Computer Science        139
# 19      usman.rafiq@nu.edu.pk        Computer Science        139
# 20   hurmat.hidayat@nu.edu.pk        Computer Science        140
# 21      fariba.laiq@nu.edu.pk        Computer Science        139
# 22     usman.abbasi@nu.edu.pk  Electrical Engineering        143
# 23       asif.iqbal@nu.edu.pk  Electrical Engineering        130
# 24      suleman.mir@nu.edu.pk  Electrical Engineering        136
# 25           m.asif@nu.edu.pk  Electrical Engineering        116
# 26      rahat.ehsan@nu.edu.pk  Electrical Engineering        108
# 27     maqsood.khan@nu.edu.pk  Electrical Engineering        147
# 34  http://pwr.nu.edu.pk/images/faculty/anum_rasha...
# 35   http://pwr.nu.edu.pk/images/faculty/Frame 52.png
# 36  http://pwr.nu.edu.pk/images/faculty/Osama_Sohr...
# 37  http://pwr.nu.edu.pk/images/faculty/Ikram_Ulla...
# 38  http://pwr.nu.edu.pk/images/faculty/Askar_Ali1...
# 39  http://pwr.nu.edu.pk/images/faculty/WhatsApp I...
# 40  http://pwr.nu.edu.pk/images/faculty/Abida_Fari...

# %%
df_pwr.dtypes
# Out:
# ID                              int64
# Name                           object
# Designation                    object
# HEC Approved PHD Supervisor      bool
# Highest Education              object
# Email                          object
# Department                     object
# Extension                       int64
# ImageURL                       object
# dtype: object

# %%
df_pwr = df_pwr.convert_dtypes()

# %%
df_pwr.dtypes
# Out:
# ID                               Int64
# Name                            string
# Designation                     string
# HEC Approved PHD Supervisor    boolean
# Highest Education               string
# Email                           string
# Department                      string
# Extension                        Int64
# ImageURL                        string
# dtype: object

# %%
df_pwr.to_csv("pwr.csv")

# %% [markdown]
# ## Concatenating DataFrames

# %%
all_faculty = pd.concat([df_lhr, df_cfd, df_pwr])

# %%
all_faculty
# Out:
#       ID                      Name          Designation  \
# 0   1238          Dr. Kashif Zafar            Professor
# 1   4391  Dr. Asif Mahmood Gillani            Professor
# 2   5424         Dr. Hammad Naveed            Professor
# 3   6174            Dr. Arshad Ali  Associate Professor
# 4   6113           Dr. Asma Naseer  Associate Professor
# ..   ...                       ...                  ...
# 36    54          Mr. Osama Sohrab             Lecturer
# 37    53           Mr. Ikram Ullah  Assistant Professor
# 38    52             Mr. Askar Ali             Lecturer
# 39    51           Ms. Noreen Shah             Lecturer
# 40    50           Ms. Abida Farid             Lecturer
#
#     HEC Approved PHD Supervisor  \
# 0                          True
# 1                          True
# 2                          True
# 3                          True
# 4                          True
# ..                          ...
# 36                        False
# 37                        False
# 38                        False
# 39                        False
# 40                        False
#
#                                     Highest Education  \
# 0   Ph.D(Computer Science), NUCES, Islamabad, Paki...
# 1   Ph.D(Computing), University of Patras , Greece...
# 2   Ph.D. (Bioengineering), The University of Illi...
# 3   PhD (CS), University of Paris VI (UPMC) Paris,...
# 4                       PhD (CS), NUCES, Lahore, 2018
# ..                                                ...
# 36  M.S (Applied Mathematics), Ghulam Ishaq Khan I...
# 37                                                  #
# 38                                                  #
# 39               Ph.D. Scholar (Coursework completed)
# 40  •	MPhil in English Language & Communication fr...
#
#                       Email              Department  Extension  \
# 0    kashif.zafar@nu.edu.pk        Computer Science        221
# 1     asif.gilani@nu.edu.pk        Computer Science        291
# 2   hammad.naveed@nu.edu.pk        Computer Science        227
# 3     arshad.ali1@nu.edu.pk        Computer Science        406
# 4     asma.naseer@nu.edu.pk        Computer Science        410
# ..                      ...                     ...        ...
# 36   osama.sohrab@nu.edu.pk  Science and Humanities        144
# 37    ikram.ullah@nu.edu.pk  Science and Humanities        145
# 38      askar.ali@nu.edu.pk  Science and Humanities        145
# 39    noreen.shah@nu.edu.pk  Science and Humanities        150
# 40   abida.farid@nu.edu.pk   Science and Humanities        140
#
#                                              ImageURL
# 0   https://lhr.nu.edu.pk/media/Faculty/02_-_Dr._K...
# 328  http://pwr.nu.edu.pk/images/faculty/Askar_Ali1...
# 329  http://pwr.nu.edu.pk/images/faculty/WhatsApp I...
# 330  http://pwr.nu.edu.pk/images/faculty/Abida_Fari...
#
# [331 rows x 9 columns]

# %%
all_faculty.dtypes
# Out:
# ID                               Int64
# Name                            string
# Designation                     string
# HEC Approved PHD Supervisor    boolean
# Highest Education               string
# Email                           string
# Department                      string
# Extension                        Int64
# ImageURL                        string
# dtype: object

# %%
all_faculty.to_csv("fast_faculty.csv")

# %% [markdown]
# ## Sampling the Faculty DataFrame

# %%
faculty = pd.read_csv("fast_faculty.csv")

# %%
faculty
# Out:
#      Unnamed: 0      ID                      Name          Designation  \
# 0             0  1238.0          Dr. Kashif Zafar            Professor
# 1             1  4391.0  Dr. Asif Mahmood Gillani            Professor
# 2             2  5424.0         Dr. Hammad Naveed            Professor
# 3             3  6174.0            Dr. Arshad Ali  Associate Professor
# 4             4  6113.0           Dr. Asma Naseer  Associate Professor
# ..          ...     ...                       ...                  ...
# 326         326    54.0          Mr. Osama Sohrab             Lecturer
# 327         327    53.0           Mr. Ikram Ullah  Assistant Professor
# 328         328    52.0             Mr. Askar Ali             Lecturer
# 329         329    51.0           Ms. Noreen Shah             Lecturer
# 330         330    50.0           Ms. Abida Farid             Lecturer
#
#      HEC Approved PHD Supervisor  \
# 0                           True
# 1                           True
# 2                           True
# 3                           True
# 4                           True
# ..                           ...
# 326                        False
# 327                        False
# 328                        False
# 329                        False
# 330                        False
#
#                                      Highest Education  \
# 0    Ph.D(Computer Science), NUCES, Islamabad, Paki...
# 1    Ph.D(Computing), University of Patras , Greece...
# 2    Ph.D. (Bioengineering), The University of Illi...
# 3    PhD (CS), University of Paris VI (UPMC) Paris,...
# 4                        PhD (CS), NUCES, Lahore, 2018
# ..                                                 ...
# 326  M.S (Applied Mathematics), Ghulam Ishaq Khan I...
# 327                                                  #
# 328                                                  #
# 329               Ph.D. Scholar (Coursework completed)
# 330  •\tMPhil in English Language & Communication f...
#
#                        Email              Department  Extension  \
# 0     kashif.zafar@nu.edu.pk        Computer Science      221.0
# 1      asif.gilani@nu.edu.pk        Computer Science      291.0
# 2    hammad.naveed@nu.edu.pk        Computer Science      227.0
# 3      arshad.ali1@nu.edu.pk        Computer Science      406.0
# 4      asma.naseer@nu.edu.pk        Computer Science      410.0
# ..                       ...                     ...        ...
# 326   osama.sohrab@nu.edu.pk  Science and Humanities      144.0
# 327    ikram.ullah@nu.edu.pk  Science and Humanities      145.0
# 328      askar.ali@nu.edu.pk  Science and Humanities      145.0
# 329    noreen.shah@nu.edu.pk  Science and Humanities      150.0
# 330   abida.farid@nu.edu.pk   Science and Humanities      140.0
#
#                                               ImageURL
# 0    https://lhr.nu.edu.pk/media/Faculty/02_-_Dr._K...
# 1    https://lhr.nu.edu.pk/media/Faculty/03_-_Dr._A...
# 2    https://lhr.nu.edu.pk/media/Faculty/01_-_Dr._H...
# 3    https://lhr.nu.edu.pk/media/Faculty/04_-_Dr._A...
# 4    https://lhr.nu.edu.pk/media/Faculty/Dr_Asma_Na...
# ..                                                 ...
# 326  http://pwr.nu.edu.pk/images/faculty/Osama_Sohr...
# 327  http://pwr.nu.edu.pk/images/faculty/Ikram_Ulla...
# 328  http://pwr.nu.edu.pk/images/faculty/Askar_Ali1...
# 329  http://pwr.nu.edu.pk/images/faculty/WhatsApp I...
# 330  http://pwr.nu.edu.pk/images/faculty/Abida_Fari...
#
# [331 rows x 10 columns]

# %%
faculty.drop('Unnamed: 0', axis=1, inplace=True)

# %%
faculty.dtypes
# Out:
# ID                             float64
# Name                            object
# Designation                     object
# HEC Approved PHD Supervisor       bool
# Highest Education               object
# Email                           object
# Department                      object
# Extension                      float64
# ImageURL                        object
# dtype: object

# %%
faculty = faculty.convert_dtypes()

# %%
faculty.dtypes
# Out:
# ID                               Int64
# Name                            string
# Designation                     string
# HEC Approved PHD Supervisor    boolean
# Highest Education               string
# Email                           string
# Department                      string
# Extension                        Int64
# ImageURL                        string
# dtype: object

# %%
# Roll Number: 20L-1011 => 1/10 = 0.1
sample_ = faculty.sample(frac=0.1)

# %%
sample_
# Out:
#          ID                    Name          Designation  \
# 167    5438        Mr. Abdul Sattar             Lecturer
# 6      4261         Dr. Saira Karim  Associate Professor
# 319      71    Mr. Syed Mohsin Shah             Lecturer
# 196    4814       Ms. Maria Maqsood  Assistant Professor
# 4      6113         Dr. Asma Naseer  Associate Professor
# 216    6087     Mr. Muhammad Hannan             Lecturer
# 262    5109       Dr. Haris Khurram  Assistant Professor
# 213    4912      Mr. Mazhar Hussain             Lecturer
# 193    4793        Mr. Adeel Ashraf  Assistant Professor
# 272  508272     Mr. Muhammad Shoaib             Lecturer
# 160    9173         Dr. Tayyaba Naz  Assistant Professor
# 182    <NA>  Mr. Hafiz Umair Gulzar  Lecturer (Islamiat)
# 170    4397  Mr. Hafiz Hamza Janjua             Lecturer
# 38     6268    Mr. Saifullah Tanvir             Lecturer
# 251    4820        Dr. Arslan Ahmed  Associate Professor
# 201    6105        Mr. Abdul Qadeer             Lecturer
# 237    6086         Ms. Anmol Bilal             Lecturer
# 176    5337         Ms. Sarah Ahmad             Lecturer
# 277  508277      Ms. Zainab Mubarik             Lecturer
# 194    4797         Ms. Asma Sattar  Assistant Professor
# 275  508449        Mr. Rizwan Ullah             Lecturer
# 7      6418        Dr. Ammar Haider  Assistant Professor
# 307      57          Usama Musharaf             Lecturer
# 198    4829        Ms. Rida Ghafoor  Assistant Professor
# 13     6048    Dr. Zeeshan Ali Khan  Assistant Professor
# 247  508167         Mr. Saqib Ameer           Instructor
# 45     6663         Ms. Zoha Waheed           Instructor
# 178    6567    Ms. Mahnoor Chaudhry           Instructor
# 325      88         Dr. Ihsan Ullah  Assistant Professor
# 118    5084         Mr. Waqas Ajmal             Lecturer
# 278  507931       Ms. Zartash Naqvi             Lecturer
# 221  506519          Mr. Muiz Qadir             Lecturer
# 214    4915      Mr. Mughees Ismail             Lecturer
#
#      HEC Approved PHD Supervisor  \
# 167                        False
# 6                           True
# 319                        False
# 196                        False
# 4                           True
# 216                        False
# 262                         True
# 213                        False
# 193                        False
# 272                        False
# 160                         True
# 182                        False
# 170                        False
# 38                         False
# 251                         True
# 201                        False
# 237                        False
# 176                        False
# 277                        False
# 194                        False
# 275                        False
# 7                          False
# 307                        False
# 198                        False
# 13                          True
# 247                        False
# 45                         False
# 178                        False
# 325                         True
# 118                        False
# 278                        False
# 221                        False
# 214                        False
#
#                                      Highest Education  \
# 167  M.Phil(Pakistan Studies), Quaid-i- Azam Univer...
# 6    Ph.D(Computer Science), NUCES, Lahore, Pakista...
# 319  B.Sc(Electrical Engineering), UET, Peshawar, P...
# 196  MS (Computer Science), NUCES FAST, Islamabad, ...
# 4                        PhD (CS), NUCES, Lahore, 2018
# 216  MS (Computer Science), National University of ...
# 262  PhD (Statistics), Bahauddin Zakariya Universit...
# 213  M.S (Computer Science), 2019
# FAST-NUCES, Chini...
# 193  M.S (Computer Science), NUCES-FAST Islamabad, ...
# 272                 MS(Math), FAST NUCES, Lahore, 2019
# 160  Ph.D (Mathematics), National University of Com...
# 182       M.Phil (Islamic Studies), GCU, Lahore (2019)
# 170  M.A(Islamic Studies), University of the Punjab...
# 38     BS (CS), Forman Christian College, Lahore, 2017
# 251  Ph.D. Electrical Engineering (Control Systems)...
# 201  BS Computer Science, National Textile Universi...
# 237                    MS (Software Engineering), 2020
# 176  M.Phil(Statistics),University of the Punjab, L...
# 277  MS(Applied Linguistics), FAST NUCES, Lahore, 2021
# 194  M.S (Software Engineering), UET Taxila, Pakist...
# 275  Master in Arts (Islamic Studies) Islamic Unive...
# 7                   PhD (CS), Monash University (2013)
# 307  MS(CS), CECOS University of IT & Emerging Scie...
# 198  M.S(Software Engineering), UET, Taxila, Pakist...
# 13   PhD (Wireless Sensor Networks), University of ...
# 247  MS Computer Science, University of Agriculture...
# 45                            BS, NUCES, Lahore (2018)
# 178  M.A  (English), University of Education, Lahor...
# 325  PhD (Finance),  Institute of Management Scienc...
# 118  MS (Civil Engineering), NUCES, Lahore, Pakista...
# 278  MS in Clinical Psychology from Government Coll...
# 221  Masters in Computer Science, 2021. (University...
# 214  Bachelor of Science (Computer Science), FAST N...
#
#                            Email                            Department  \
# 167       abdul.sattar@nu.edu.pk                  Science & Humanities
# 6          saira.karim@nu.edu.pk                      Computer Science
# 319        mohsin.shah@nu.edu.pk                Electrical Engineering
# 196      maria.maqsood@nu.edu.pk        Department of Computer Science
# 4          asma.naseer@nu.edu.pk                      Computer Science
# 216      hannan.farooq@nu.edu.pk        Department of Computer Science
# 262      haris.khurram@nu.edu.pk   Department of Sciences & Humanities
# 213           mazhar.h@nu.edu.pk        Department of Computer Science
# 193       adeel.cheema@nu.edu.pk        Department of Computer Science
# 272           m.shoaib@nu.edu.pk   Department of Sciences & Humanities
# 160        tayyaba.naz@nu.edu.pk                  Science & Humanities
# 182       umair.gulzar@nu.edu.pk                  Science & Humanities
# 170       hamza.janjua@nu.edu.pk                  Science & Humanities
# 38    saifullah.tanvir@nu.edu.pk                      Computer Science
# 251        arslan.amin@nu.edu.pk  Department of Electrical Engineering
# 201           a.qadeer@nu.edu.pk        Department of Computer Science
# 237                         <NA>    Department of Software Engineering
# 176        Sarah.ahmad@nu.edu.pk                  Science & Humanities
# 277     zainab.mubarik@nu.edu.pk   Department of Sciences & Humanities
# 194        asma.sattar@nu.edu.pk        Department of Computer Science
